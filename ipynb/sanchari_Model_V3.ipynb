# %%
# %ls
# Out:
# check_coords.py  main_v3.py        requirements.txt         train_v3.py
# dataset_v3.py    model_v3.py       Sanchari_Model_V3.ipynb  venv/
# geotiff_info.py  preprocess_v3.py  test_v3.py

# %%
# !python preprocess_v3.py
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/balraj98/deepglobe-road-extraction-dataset
# License(s): other
# ...
# 100%|██████████████████████████████████████| 3.79G/3.79G [03:36<00:00, 18.8MB/s]
#
# Unzipping data/raw/deepglobe-road-extraction-dataset.zip...
# Download and extraction complete.
# Starting preprocessing (Tiling 1024x1024 -> 256x256)...
# Found 8570 source images.
# 100%|███████████████████████████████████████| 8570/8570 [01:33<00:00, 91.32it/s]
# Preprocessing done. Data saved to data/processed/train

# %%
# !python train_v3.py
# Out:
# Starting V3 training process...
# Using device: cuda
# /home/labadmin/Downloads/sancharimodel/dataset_v3.py:73: UserWarning: Argument(s) 'alpha_affine' are not valid for transform ElasticTransform
#   A.ElasticTransform(p=0.3, alpha=120, sigma=120 * 0.05, alpha_affine=None), # alpha_affine deprecated
# /home/labadmin/Downloads/sancharimodel/venv/lib/python3.11/site-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# config.json: 100%|█████████████████████████████| 156/156 [00:00<00:00, 1.01MB/s]
# model.safetensors: 100%|███████████████████| 87.3M/87.3M [00:03<00:00, 22.1MB/s]
#
# --- Epoch 1/75 ---
# ...
# Validation: 100%|█████████████| 934/934 [00:09<00:00, 101.22it/s, val_iou=0.519]
# Summary: Train Loss: 0.3921 | Val Loss: 0.3142 | Val IoU: 0.5264 | LR: 0.000100
# => Saving checkpoint to checkpoint_v3.pth
# ...

# %%
# !python optimize_threshold_v3.py
# Out:
# Optimizing threshold using device: cuda
# Evaluating on 14943 validation images.
# Running inference with TTA...
# 100%|█████████████████████████████████████████| 934/934 [00:33<00:00, 27.63it/s]
# Searching for optimal threshold...
# Threshold 0.10: IoU = 0.6426
# Threshold 0.15: IoU = 0.6431
# Threshold 0.20: IoU = 0.6437
# Threshold 0.25: IoU = 0.6559
# Threshold 0.30: IoU = 0.6579
# Threshold 0.35: IoU = 0.6581
# Threshold 0.40: IoU = 0.6583
# Threshold 0.45: IoU = 0.6585
# Threshold 0.50: IoU = 0.6585
# Threshold 0.55: IoU = 0.6573
# Threshold 0.60: IoU = 0.6572
# Threshold 0.65: IoU = 0.6570
# Threshold 0.70: IoU = 0.6569
# Threshold 0.75: IoU = 0.6458
# Threshold 0.80: IoU = 0.6412
# Threshold 0.85: IoU = 0.6407
#
# --- Result ---
# Best Threshold: 0.45
# Best IoU:       0.6585
# Improvement:    0.0000 over default (0.5)
