# %%
 from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
PROJECT_PATH = '/content/drive/MyDrive/projects/sanchari-model'
# !mkdir -p "{PROJECT_PATH}"
# %cd "{PROJECT_PATH}"
# Out:
# /content/drive/MyDrive/projects/sanchari-model

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 91.2 MB/s eta 0:00:00
# ...

# %%
# !python preprocess.py
# Out:
# Starting preprocessing...
# Raw data directory: data/raw/train
# Processed data directory: data/processed/train
# Found 4053 satellite images to process.
# Tiling images and masks:  25% 1000/4053 [36:42<1:52:05,  2.20s/it]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/projects/sanchari-model/preprocess.py", line 87, in <module>
#     main()
#   File "/content/drive/MyDrive/projects/sanchari-model/preprocess.py", line 81, in main
#     tile_image(img_path, mask_path, PROCESSED_DATA_DIR)
#   File "/content/drive/MyDrive/projects/sanchari-model/preprocess.py", line 53, in tile_image
#     cv2.imwrite(img_patch_path, img_patch)
# KeyboardInterrupt
# ^C

# %%
# !python train.py
# Out:
# Starting training process...
# Using device: cuda
# Training samples: 10433
# Validation samples: 1842
#
# --- Epoch 1/25 ---
# Training: 100% 653/653 [34:38<00:00,  3.18s/it, loss=0.41]
# Validation: 100% 116/116 [04:51<00:00,  2.51s/it, val_iou=0.0243]
# Epoch 1 Summary:
#   Train Loss: 0.2592
#   Val Loss:   0.1725
#   Val IoU:    0.0014
#   -> New best model saved to best_model.pth (IoU: 0.0014)
#
# --- Epoch 2/25 ---
# Training: 100% 653/653 [06:51<00:00,  1.59it/s, loss=0.292]
# Validation: 100% 116/116 [00:24<00:00,  4.69it/s, val_iou=0.446]
# Epoch 2 Summary:
#   Train Loss: 0.1513
#   Val Loss:   0.1300
#   Val IoU:    0.2265
#   -> New best model saved to best_model.pth (IoU: 0.2265)
#
# --- Epoch 3/25 ---
# Training: 100% 653/653 [06:51<00:00,  1.58it/s, loss=0.316]
# Validation: 100% 116/116 [00:24<00:00,  4.75it/s, val_iou=0.655]
# Epoch 3 Summary:
#   Train Loss: 0.1109
#   Val Loss:   0.1034
#   Val IoU:    0.2671
# ...

# %%
# !python predict.py --input-folder test-images --output-folder predicted
# Out:
# Starting inference...
# Using device: cuda
# Model loaded from best_model.pth
# Predicting masks: 100% 17/17 [00:18<00:00,  1.09s/it]
#
# Inference complete. Masks saved to predicted

# %%
# !python optimize_threshold.py
# Out:
# Starting threshold optimization for the initial model...
# Using device: cpu
# Model loaded from best_model.pth
# Using 1862 validation samples to find the best threshold.
# Gathering predictions from validation set...
# Predicting:   0% 0/59 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Predicting: 100% 59/59 [1:07:13<00:00, 68.37s/it]
#
# Searching for optimal threshold...
# Thresholding:   0% 0/31 [00:00<?, ?it/s]  New best IoU: 0.5619 at threshold: 0.20
# Thresholding:   3% 1/31 [00:01<00:31,  1.05s/it]  New best IoU: 0.5739 at threshold: 0.22
# Thresholding:   6% 2/31 [00:01<00:26,  1.09it/s]  New best IoU: 0.5826 at threshold: 0.24
# Thresholding:  10% 3/31 [00:02<00:25,  1.09it/s]  New best IoU: 0.5892 at threshold: 0.26
# ...

# %%
# !python train_v2.py
# Out:
# Starting V2 training process...
# Using device: cuda
# /content/drive/MyDrive/projects/sanchari-model/dataset_v2.py:73: UserWarning: Argument(s) 'alpha_affine' are not valid for transform ElasticTransform
#   A.ElasticTransform(p=0.2, alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03),
# Training samples: 10546, Validation samples: 1862
# config.json: 100% 156/156 [00:00<00:00, 1.36MB/s]
# model.safetensors: 100% 87.3M/87.3M [00:01<00:00, 79.7MB/s]
#
# --- Epoch 1/75 ---
# Training: 100% 660/660 [43:23<00:00,  3.94s/it, loss=0.649]
# Validation: 100% 117/117 [06:28<00:00,  3.32s/it, val_iou=0.313]
# Summary: Train Loss: 0.7096 | Val Loss: 0.4988 | Val IoU: 0.4503 | LR: 0.000100
# ...

# %%
# !python predict_v2.py --input-folder test-images --output-folder predictedv2
# Out:
# Starting V2 inference...
# Using device: cpu
# config.json: 100% 156/156 [00:00<00:00, 913kB/s]
# model.safetensors: 100% 87.3M/87.3M [00:01<00:00, 67.4MB/s]
# Model loaded from best_model_v2.pth
# Predicting masks: 100% 17/17 [02:07<00:00,  7.51s/it]
#
# Inference complete. Masks saved to predictedv2

# %%
# !python train_v2.py
# Out:
# Starting V2 training process...
# Using device: cuda
# /content/drive/MyDrive/projects/sanchari-model/dataset_v2.py:73: UserWarning: Argument(s) 'alpha_affine' are not valid for transform ElasticTransform
#   A.ElasticTransform(p=0.2, alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03),
# Training samples: 10546, Validation samples: 1862
# config.json: 100% 156/156 [00:00<00:00, 636kB/s]
# model.safetensors: 100% 87.3M/87.3M [00:01<00:00, 79.8MB/s]
#
# --- Epoch 1/75 ---
# Training: 100% 660/660 [32:49<00:00,  2.98s/it, loss=0.421]
# Validation: 100% 117/117 [04:50<00:00,  2.48s/it, val_iou=0.109]
# Summary: Train Loss: 0.5922 | Val Loss: 0.4227 | Val IoU: 0.4483 | LR: 0.000100
# ...

# %%
# !python geotiff_info.py
# Out:
# Number of Bands: 3
# Data Type (Bit Depth): uint8
#
# Band Information:
#   - Band 1
#   - Band 2
#   - Band 3
